# %%
# sklearn을 활용하여 breast_cancer 불러옴
from sklearn.datasets import load_breast_cancer
bc = load_breast_cancer()

# 독립변수와 종속변수로 각자 데이터셋을 나눠서 저장
X = bc.data
y = bc.target

# %%
# pandas를 활용하여 기초 통계 도출
import pandas as pd

df = pd.DataFrame(X)
df.describe()
# Out:
#                0           1           2            3           4   \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    14.127292   19.289649   91.969033   654.889104    0.096360
# std      3.524049    4.301036   24.298981   351.914129    0.014064
# min      6.981000    9.710000   43.790000   143.500000    0.052630
# 25%     11.700000   16.170000   75.170000   420.300000    0.086370
# 50%     13.370000   18.840000   86.240000   551.100000    0.095870
# 75%     15.780000   21.800000  104.100000   782.700000    0.105300
# max     28.110000   39.280000  188.500000  2501.000000    0.163400
#
#                5           6           7           8           9   ...  \
# count  569.000000  569.000000  569.000000  569.000000  569.000000  ...
# mean     0.104341    0.088799    0.048919    0.181162    0.062798  ...
# std      0.052813    0.079720    0.038803    0.027414    0.007060  ...
# min      0.019380    0.000000    0.000000    0.106000    0.049960  ...
# ...

# %%
# StandaraScaler와 train_test_split을 scikit-learn에서 import
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
# breast_cancer 데이터를 train_test_split을 활용하여 train set, test set으로 분리
X_train, X_test, y_train, y_test = train_test_split(
    # 층화추출 활용, random_state는 42로 고정
    X, y, stratify=y, random_state=42
)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# StandardScaler(평균, 표준편차)를 활용하여 정규화 
scaler = StandardScaler()
X_train_zs = scaler.fit_transform(X_train)
X_test_zs = scaler.transform(X_test)

# Neural Network 활용은 01과 같음
bc_nn = MLPClassifier((64, 128, 64))
bc_nn.fit(X_train_zs, y_train)
pred = bc_nn.predict(X_test_zs)
print(accuracy_score(y_test, pred))
print(confusion_matrix(y_test, pred))
# Out:
# 0.972027972027972
# [[52  1]
#  [ 3 87]]
